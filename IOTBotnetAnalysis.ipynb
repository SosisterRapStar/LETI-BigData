# %% [markdown]
# <a href="https://colab.research.google.com/github/SosisterRapStar/LETI-BigData/blob/master/IOTBotnetAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

path = kagglehub.dataset_download("mkashifn/nbaiot-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.75G/1.75G [00:22<00:00, 82.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mkashifn/nbaiot-dataset/versions/1
